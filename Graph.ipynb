# %% [markdown]
# *   Name: Brinda Gupta
# *   Enrollment Number: 19/11/EC/001
# *   Branch: CSE
# *   Email: brindagupta2002@gmail.com

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("/content/drive/MyDrive/MTech/Experiment/Inference.csv")

# %%
df
# Out:
#    Fault Percentage of Single Layer  Inference accuracy of Single Layer  \
# 0                           0.00000                               90.38
# 1                           2.09977                               57.96
# 2                           4.28629                               23.47
# 3                           6.26623                               30.52
# 4                           8.34319                               21.63
# 5                          10.36633                               11.37
# 6                          12.27590                               11.94
# 7                          14.26194                                9.89
#
#    Fault Percentage of Triple Layer  Inference accuracy of Triple Layer
# 0                           0.00000                               90.38
# 1                           2.11359                               72.30
# 2                           4.21941                               38.37
# ...

# %%
print(df.columns)
# Out:
# Index(['Fault Percentage of Single Layer',
#        'Inference accuracy of Single Layer',
#        'Fault Percentage of Triple Layer',
#        'Inference accuracy of Triple Layer'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6)) # Adjust figure size if needed

plt.plot(df["Fault Percentage of Single Layer"], df["Inference accuracy of Single Layer"], 'bo-', label="Single-layer memristor based neural network")
plt.plot(df["Fault Percentage of Triple Layer"], df["Inference accuracy of Triple Layer"], 'ro-', label="Triple-layer memristor based neural network")

plt.xlabel("Percentage of faults (%)")
plt.ylabel("Accuracy percentage (%)")
plt.legend()
# Display the plot
plt.grid(True)
#plt.show()
# Increase DPI for higher resolution
plt.savefig('/content/drive/MyDrive/MTech/Experiment/Comparison3.png', dpi=1200)  # Replace 'my_plot.png' with your desired filenam
